# %%
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')

"""
Plotting
"""
import matplotlib as mpl
#mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.size'] = 16
mpl.rcParams['font.family'] = 'Arial'

# %%
import pandas as pd
import os

# %%
#Entirety of Drill core data:
df = pd.read_csv('../data/Drill_core_lithologies.csv')

# %% [markdown]
# **Gathering Drill Core Data:**

# %%
df.head() #From
# Out:
#            Sample       Lithology/chemistry   K2O   CaO  TiO2   SiO2  Al2O3  \
# 0     90_2_48_50b  Granitoid (clast in UIM)  3.03  2.46  0.23  71.43  12.43
# 1      93_2_16_17  Granitoid (clast in UIM)  3.43  2.55  0.37  72.09  14.52
# 2      94_3_36_38  Granitoid (clast in UIM)  4.87  1.72  0.28  71.75  13.76
# 3      95_2_20_22  Granitoid (clast in UIM)  5.79  1.08  0.14  71.97  14.09
# 4  95_2_89.5_91.5  Granitoid (clast in UIM)  3.11  0.91  0.20  75.80  11.64
#
#    Na2O   MgO   FeO   MnO   SO3  P2O5  Cl   Total  Unnamed: 15  Unnamed: 16  \
# 0  4.65  0.18  2.31  0.05  0.20  0.06 NaN   99.35          NaN          NaN
# 1  4.05  0.80  2.04  0.03   NaN  0.09 NaN  101.05          NaN          NaN
# 2  3.76  0.97  1.83  0.02   NaN  0.07 NaN  100.78          NaN          NaN
# 3  3.78  0.52  0.64  0.01   NaN  0.02 NaN   99.28          NaN          NaN
# 4  4.15  0.72  1.27  0.01  0.04  0.09 NaN   99.38          NaN          NaN
#
#                                 Unnamed: 17
# ...

# %%
granitoid = pd.read_csv('../data/Chix_lith_granitoid.csv', header=0)
dolerite = pd.read_csv('../data/Chix_lith_dolerite.csv', header=0)
Felsite = pd.read_csv('../data/Chix_lith_Felsite.csv', header=0)
Dacite = pd.read_csv('../data/Chix_lith_Dacite.csv', header=0)
UIM = pd.read_csv('../data/Chix_lith_UIM.csv', header=0)
LIMB = pd.read_csv('../data/Chix_lith_LIMB.csv', header=0)

# %% [markdown]
# **Gathering Tektite Data:**

# %%
#this study's data:
fin_data = pd.read_csv('../data/geochem_data.csv', header=0)
fin_data['sample_no'] = [i[1] for i in fin_data['Sample'].str.split('_')]

#Previous studies data:
bermudez = pd.read_csv('../data/Bermudez.csv', header=0)
belza=pd.read_csv('../data/Belza.csv', header=0)
izett=pd.read_csv('../data/izett.csv', header=0)
kbrl_blck=pd.read_csv('../data/koeberl_black.csv', header=0)
kbrl_ylw=pd.read_csv('../data/koeberl_yellow.csv', header=0)

# %% [markdown]
# # **Inputting data of Oxides:**

# %%
features = ['K2O', 'CaO', 'TiO2', 'Al2O3', 'Na2O', 'MgO', 'FeO', 'MnO'] #For tektites & drill cores

# %% [markdown]
# # Making KDE plots:

# %%
#Making subplots:
nrow = 4; ncol = 2;
fig, axs = plt.subplots(nrows=nrow, ncols=ncol, sharex=True, figsize=(13, 16))
fig.suptitle('Drill core data (Test plot)')

#Adding y-labels 
i=0
for ax in axs.reshape(-1): 
    ax.set_ylabel(features[i]+ ' (Wt%) ')
    i = i + 1
    
#Plotting data:
colors = ['#EA9314', '#418C34', '#F2EF2B', '#25F0ED', '#FA3B3B', '#A75FE7']

#K2O:
sns.kdeplot(ax=axs[0,0],x = granitoid['SiO2'],y = granitoid[features[0]],
            levels=2, alpha = 0.5, color = colors[0], shade = True)
sns.kdeplot(ax=axs[0,0],x = dolerite['SiO2'],y = dolerite[features[0]],
            levels=2, alpha = 0.5, color = colors[1], shade = True)
sns.kdeplot(ax=axs[0,0],x = Felsite['SiO2'],y = Felsite[features[0]],
            levels=2, alpha = 0.5, color = colors[2], shade = True)
sns.kdeplot(ax=axs[0,0],x = Dacite['SiO2'],y = Dacite[features[0]],
            levels=2, alpha = 0.5, color = colors[3], shade = True)
sns.kdeplot(ax=axs[0,0],x = UIM['SiO2'],y = UIM[features[0]],
            levels=2, alpha = 0.5, color = colors[4], shade = True)
sns.kdeplot(ax=axs[0,0],x = LIMB['SiO2'],y = LIMB[features[0]],
            levels=2, alpha = 0.5, color = colors[5], shade = True)
#CaO:
sns.kdeplot(ax=axs[0,1],x = granitoid['SiO2'],y = granitoid[features[1]],
            levels=2, alpha = 0.5, color = colors[0], shade = True)
sns.kdeplot(ax=axs[0,1],x = dolerite['SiO2'],y = dolerite[features[1]],
            levels=2, alpha = 0.5, color = colors[1], shade = True)
sns.kdeplot(ax=axs[0,1],x = Felsite['SiO2'],y = Felsite[features[1]],
            levels=2, alpha = 0.5, color = colors[2], shade = True)
sns.kdeplot(ax=axs[0,1],x = Dacite['SiO2'],y = Dacite[features[1]],
            levels=2, alpha = 0.5, color = colors[3], shade = True)
sns.kdeplot(ax=axs[0,1],x = UIM['SiO2'],y = UIM[features[1]],
            levels=2, alpha = 0.5, color = colors[4], shade = True)
sns.kdeplot(ax=axs[0,1],x = LIMB['SiO2'],y = LIMB[features[1]],
            levels=2, alpha = 0.5, color = colors[5], shade = True)
#TiO2:
sns.kdeplot(ax=axs[1,0],x = granitoid['SiO2'],y = granitoid[features[2]],
            levels=2, alpha = 0.5, color = colors[0], shade = True)
sns.kdeplot(ax=axs[1,0],x = dolerite['SiO2'],y = dolerite[features[2]],
            levels=2, alpha = 0.5, color = colors[1], shade = True)
sns.kdeplot(ax=axs[1,0],x = Felsite['SiO2'],y = Felsite[features[2]],
            levels=2, alpha = 0.5, color = colors[2], shade = True)
sns.kdeplot(ax=axs[1,0],x = Dacite['SiO2'],y = Dacite[features[2]],
            levels=2, alpha = 0.5, color = colors[3], shade = True)
sns.kdeplot(ax=axs[1,0],x = UIM['SiO2'],y = UIM[features[2]],
            levels=2, alpha = 0.5, color = colors[4], shade = True)
sns.kdeplot(ax=axs[1,0],x = LIMB['SiO2'],y = LIMB[features[2]],
            levels=2, alpha = 0.5, color = colors[5], shade = True)
#Al2O3:
sns.kdeplot(ax=axs[1,1],x = granitoid['SiO2'],y = granitoid[features[3]],
            levels=2, alpha = 0.5, color = colors[0], shade = True)
sns.kdeplot(ax=axs[1,1],x = dolerite['SiO2'],y = dolerite[features[3]],
            levels=2, alpha = 0.5, color = colors[1], shade = True)
sns.kdeplot(ax=axs[1,1],x = Felsite['SiO2'],y = Felsite[features[3]],
            levels=2, alpha = 0.5, color = colors[2], shade = True)
sns.kdeplot(ax=axs[1,1],x = Dacite['SiO2'],y = Dacite[features[3]],
            levels=2, alpha = 0.5, color = colors[3], shade = True)
sns.kdeplot(ax=axs[1,1],x = UIM['SiO2'],y = UIM[features[3]],
            levels=2, alpha = 0.5, color = colors[4], shade = True)
sns.kdeplot(ax=axs[1,1],x = LIMB['SiO2'],y = LIMB[features[3]],
            levels=2, alpha = 0.5, color = colors[5], shade = True)
#Na2O:
sns.kdeplot(ax=axs[2,0],x = granitoid['SiO2'],y = granitoid[features[4]],
            levels=2, alpha = 0.5, color = colors[0], shade = True)
sns.kdeplot(ax=axs[2,0],x = dolerite['SiO2'],y = dolerite[features[4]],
            levels=2, alpha = 0.5, color = colors[1], shade = True)
sns.kdeplot(ax=axs[2,0],x = Felsite['SiO2'],y = Felsite[features[4]],
            levels=2, alpha = 0.5, color = colors[2], shade = True)
sns.kdeplot(ax=axs[2,0],x = Dacite['SiO2'],y = Dacite[features[4]],
            levels=2, alpha = 0.5, color = colors[3], shade = True)
sns.kdeplot(ax=axs[2,0],x = UIM['SiO2'],y = UIM[features[4]],
            levels=2, alpha = 0.5, color = colors[4], shade = True)
sns.kdeplot(ax=axs[2,0],x = LIMB['SiO2'],y = LIMB[features[4]],
            levels=2, alpha = 0.5, color = colors[5], shade = True)
#MgO:
sns.kdeplot(ax=axs[2,1],x = granitoid['SiO2'],y = granitoid[features[5]],
            levels=2, alpha = 0.5, color = colors[0], shade = True)
sns.kdeplot(ax=axs[2,1],x = dolerite['SiO2'],y = dolerite[features[5]],
            levels=2, alpha = 0.5, color = colors[1], shade = True)
sns.kdeplot(ax=axs[2,1],x = Felsite['SiO2'],y = Felsite[features[5]],
            levels=2, alpha = 0.5, color = colors[2], shade = True)
sns.kdeplot(ax=axs[2,1],x = Dacite['SiO2'],y = Dacite[features[5]],
            levels=2, alpha = 0.5, color = colors[3], shade = True)
sns.kdeplot(ax=axs[2,1],x = UIM['SiO2'],y = UIM[features[5]],
            levels=2, alpha = 0.5, color = colors[4], shade = True)
sns.kdeplot(ax=axs[2,1],x = LIMB['SiO2'],y = LIMB[features[5]],
            levels=2, alpha = 0.5, color = colors[5], shade = True)
#FeO:
sns.kdeplot(ax=axs[3,0],x = granitoid['SiO2'],y = granitoid[features[6]],
            levels=2, alpha = 0.5, color = colors[0], shade = True)
sns.kdeplot(ax=axs[3,0],x = dolerite['SiO2'],y = dolerite[features[6]],
            levels=2, alpha = 0.5, color = colors[1], shade = True)
sns.kdeplot(ax=axs[3,0],x = Felsite['SiO2'],y = Felsite[features[6]],
            levels=2, alpha = 0.5, color = colors[2], shade = True)
sns.kdeplot(ax=axs[3,0],x = Dacite['SiO2'],y = Dacite[features[6]],
            levels=2, alpha = 0.5, color = colors[3], shade = True)
sns.kdeplot(ax=axs[3,0],x = UIM['SiO2'],y = UIM[features[6]],
            levels=2, alpha = 0.5, color = colors[4], shade = True)
sns.kdeplot(ax=axs[3,0],x = LIMB['SiO2'],y = LIMB[features[6]],
            levels=2, alpha = 0.5, color = colors[5], shade = True)
#MnO:
sns.kdeplot(ax=axs[3,1],x = granitoid['SiO2'],y = granitoid[features[7]],
            levels=2, alpha = 0.5, color = colors[0], shade = True)
sns.kdeplot(ax=axs[3,1],x = dolerite['SiO2'],y = dolerite[features[7]],
            levels=2, alpha = 0.5, color = colors[1], shade = True)
sns.kdeplot(ax=axs[3,1],x = Felsite['SiO2'],y = Felsite[features[7]],
            levels=2, alpha = 0.5, color = colors[2], shade = True)
sns.kdeplot(ax=axs[3,1],x = Dacite['SiO2'],y = Dacite[features[7]],
            levels=2, alpha = 0.5, color = colors[3], shade = True)
sns.kdeplot(ax=axs[3,1],x = UIM['SiO2'],y = UIM[features[7]],
            levels=2, alpha = 0.5, color = colors[4], shade = True)
sns.kdeplot(ax=axs[3,1],x = LIMB['SiO2'],y = LIMB[features[7]],
            levels=2, alpha = 0.5, color = colors[5], shade = True)

#Setting up legend & other graphics    
colors = ['#EA9314', '#418C34', '#F2EF2B', '#25F0ED', '#FA3B3B', '#A75FE7']
labels = ['Granitoid','Dolerite','Felsite','Dacite','UIM','LIMB']

patches = []
for i in range(len(labels)):
    patches.append(mpatches.Patch(color=colors[i],label=labels[i]))

plt.setp(axs[-1, :], xlabel='SiO$_2$ (Wt%)')
plt.xlim(40,70)
plt.tight_layout()
plt.legend(handles=patches, fontsize = 15, frameon=True, ncol=3, bbox_to_anchor=(0, -0.4))
plt.show()

# %% [markdown]
# #  Tektite Scatterplots

# %%
nrow = 4; ncol = 2;
fig, axs = plt.subplots(nrows=nrow, ncols=ncol, sharex=True, figsize=(13, 16))
# fig.suptitle('Tektite data')

ox_labels = ['K$_2$O', 'CaO', 'TiO$_2$', 'Al$_2$O$_3$', 'Na$_2$O', 'MgO', 'FeO', 'MnO'] #For tektites & drill cores

i=0
for ax in axs.reshape(-1): 
    ax.scatter(fin_data['SiO2'].tolist(), fin_data[features[i]].tolist(),color = 'black', 
               s=12,alpha=0.7,label='This Study')
    ax.scatter(bermudez['SiO2'].tolist(), bermudez[features[i]].tolist(), marker= '^',s=30,color = '#4d9221',
               label='Bermudez et al.,2016')
    ax.scatter(belza['SiO2'].tolist(), belza[features[i]].tolist(), marker= 'p',s=30,color = '#35978f',
               label='Belza et al.,2015')
    ax.scatter(izett['SiO2'].tolist(), izett[features[i]].tolist(), marker= 'o',s=30,color = '#de77ae',
               label='Izett et al., 1991')
    ax.scatter(kbrl_blck['SiO2'].tolist(), kbrl_blck[features[i]].tolist(), marker= 's',s=30,color = '#f46d43',
               label='Koeberl & Sigurddson, 1992 (black)')
    ax.scatter(kbrl_ylw['SiO2'].tolist(), kbrl_ylw[features[i]].tolist(), marker= 's',s=30,color = '#d53e4f',
               label='Koeberl & Sigurddson, 1992 (yellow)')
    ax.set_ylabel(ox_labels[i]+ ' (Wt%) ')

    i = i + 1


plt.setp(axs[-1, :], xlabel='SiO$_2$ (Wt%)')
plt.tight_layout()
ax.legend(loc = 'lower center', bbox_to_anchor=(0, -0.4),frameon=True, ncol=3, prop={'size': 12})
#plt.savefig('harker_oxides_navg.png',dpi=300, format='png',
 #           bbox_inches='tight')

plt.show()

# %% [markdown]
# # Combining KDE and scatterplots:

# %%
nrow = 4; ncol = 2;
fig, axs = plt.subplots(nrows=nrow, ncols=ncol, sharex=True, figsize=(13, 16))
fig.suptitle('Tektite and M0077A Drill Core Major Oxides')

#Drill core data: 
colors = ['#EA9314', '#418C34', '#F2EF2B', '#25F0ED', '#FA3B3B', '#A75FE7']

#K2O:
sns.kdeplot(ax=axs[0,0],x = granitoid['SiO2'],y = granitoid[features[0]],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(ax=axs[0,0],x = dolerite['SiO2'],y = dolerite[features[0]],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(ax=axs[0,0],x = Felsite['SiO2'],y = Felsite[features[0]],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(ax=axs[0,0],x = Dacite['SiO2'],y = Dacite[features[0]],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(ax=axs[0,0],x = UIM['SiO2'],y = UIM[features[0]],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(ax=axs[0,0],x = LIMB['SiO2'],y = LIMB[features[0]],
            levels=2, alpha = 0.4, color = colors[5], shade = True)
axs[0,0].set_ylim(0,2.6)

#CaO:
sns.kdeplot(ax=axs[0,1],x = granitoid['SiO2'],y = granitoid[features[1]],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(ax=axs[0,1],x = dolerite['SiO2'],y = dolerite[features[1]],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(ax=axs[0,1],x = Felsite['SiO2'],y = Felsite[features[1]],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(ax=axs[0,1],x = Dacite['SiO2'],y = Dacite[features[1]],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(ax=axs[0,1],x = UIM['SiO2'],y = UIM[features[1]],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(ax=axs[0,1],x = LIMB['SiO2'],y = LIMB[features[1]],
            levels=2, alpha = 0.4, color = colors[5], shade = True)
axs[0,1].set_ylim(0,40)

#TiO2:
sns.kdeplot(ax=axs[1,0],x = granitoid['SiO2'],y = granitoid[features[2]],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(ax=axs[1,0],x = dolerite['SiO2'],y = dolerite[features[2]],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(ax=axs[1,0],x = Felsite['SiO2'],y = Felsite[features[2]],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(ax=axs[1,0],x = Dacite['SiO2'],y = Dacite[features[2]],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(ax=axs[1,0],x = UIM['SiO2'],y = UIM[features[2]],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(ax=axs[1,0],x = LIMB['SiO2'],y = LIMB[features[2]],
            levels=2, alpha = 0.4, color = colors[5], shade = True)
axs[1,0].set_ylim(0.3,0.9)

#Al2O3:
sns.kdeplot(ax=axs[1,1],x = granitoid['SiO2'],y = granitoid[features[3]],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(ax=axs[1,1],x = dolerite['SiO2'],y = dolerite[features[3]],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(ax=axs[1,1],x = Felsite['SiO2'],y = Felsite[features[3]],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(ax=axs[1,1],x = Dacite['SiO2'],y = Dacite[features[3]],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(ax=axs[1,1],x = UIM['SiO2'],y = UIM[features[3]],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(ax=axs[1,1],x = LIMB['SiO2'],y = LIMB[features[3]],
            levels=2, alpha = 0.4, color = colors[5], shade = True)
axs[1,1].set_ylim(0,20)

#Na2O:
sns.kdeplot(ax=axs[2,0],x = granitoid['SiO2'],y = granitoid[features[4]],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(ax=axs[2,0],x = dolerite['SiO2'],y = dolerite[features[4]],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(ax=axs[2,0],x = Felsite['SiO2'],y = Felsite[features[4]],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(ax=axs[2,0],x = Dacite['SiO2'],y = Dacite[features[4]],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(ax=axs[2,0],x = UIM['SiO2'],y = UIM[features[4]],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(ax=axs[2,0],x = LIMB['SiO2'],y = LIMB[features[4]],
            levels=2, alpha = 0.4, color = colors[5], shade = True)
axs[2,0].set_ylim(0,5.5)

#MgO:
sns.kdeplot(ax=axs[2,1],x = granitoid['SiO2'],y = granitoid[features[5]],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(ax=axs[2,1],x = dolerite['SiO2'],y = dolerite[features[5]],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(ax=axs[2,1],x = Felsite['SiO2'],y = Felsite[features[5]],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(ax=axs[2,1],x = Dacite['SiO2'],y = Dacite[features[5]],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(ax=axs[2,1],x = UIM['SiO2'],y = UIM[features[5]],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(ax=axs[2,1],x = LIMB['SiO2'],y = LIMB[features[5]],
            levels=2, alpha = 0.4, color = colors[5], shade = True)
axs[2,1].set_ylim(0,10)

#FeO:
sns.kdeplot(ax=axs[3,0],x = granitoid['SiO2'],y = granitoid[features[6]],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(ax=axs[3,0],x = dolerite['SiO2'],y = dolerite[features[6]],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(ax=axs[3,0],x = Felsite['SiO2'],y = Felsite[features[6]],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(ax=axs[3,0],x = Dacite['SiO2'],y = Dacite[features[6]],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(ax=axs[3,0],x = UIM['SiO2'],y = UIM[features[6]],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(ax=axs[3,0],x = LIMB['SiO2'],y = LIMB[features[6]],
            levels=2, alpha = 0.4, color = colors[5], shade = True)
axs[3,0].set_ylim(2,10)

#MnO:
sns.kdeplot(ax=axs[3,1],x = granitoid['SiO2'],y = granitoid[features[7]],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(ax=axs[3,1],x = dolerite['SiO2'],y = dolerite[features[7]],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(ax=axs[3,1],x = Felsite['SiO2'],y = Felsite[features[7]],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(ax=axs[3,1],x = Dacite['SiO2'],y = Dacite[features[7]],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(ax=axs[3,1],x = UIM['SiO2'],y = UIM[features[7]],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(ax=axs[3,1],x = LIMB['SiO2'],y = LIMB[features[7]],
            levels=2, alpha = 0.4, color = colors[5], shade = True)
axs[3,1].set_ylim(0,0.3)

#Tektite Data:
ox_labels = ['K$_2$O', 'CaO', 'TiO$_2$', 'Al$_2$O$_3$', 'Na$_2$O', 'MgO', 'FeO', 'MnO'] #For tektites & drill cores

i=0
for ax in axs.reshape(-1): 
    ax.scatter(fin_data['SiO2'].tolist(), fin_data[features[i]].tolist(),color = 'black', 
               s=12,alpha=0.8,label='This Study')
    ax.scatter(bermudez['SiO2'].tolist(), bermudez[features[i]].tolist(), marker= '^',s=30,color = '#4d9221',
               label='Bermudez et al.,2016')
    ax.scatter(belza['SiO2'].tolist(), belza[features[i]].tolist(), marker= 'p',s=30,color = '#35978f',
               label='Belza et al.,2015')
    ax.scatter(izett['SiO2'].tolist(), izett[features[i]].tolist(), marker= 'o',s=30,color = '#de77ae',
               label='Izett et al., 1991')
    ax.scatter(kbrl_blck['SiO2'].tolist(), kbrl_blck[features[i]].tolist(), marker= 's',s=30,color = '#f46d43',
               label='Koeberl & Sigurddson, 1992 (black)')
    ax.scatter(kbrl_ylw['SiO2'].tolist(), kbrl_ylw[features[i]].tolist(), marker= 's',s=30,color = '#d53e4f',
               label='Koeberl & Sigurddson, 1992 (yellow)')
    ax.set_ylabel(ox_labels[i]+ ' (Wt%) ')

    i = i + 1

#Setting up legend & other graphics    
colors = ['#EA9314', '#418C34', '#F2EF2B', '#25F0ED', '#FA3B3B', '#A75FE7']
#           'black','#4d9221','#35978f','#de77ae', '#f46d43','#d53e4f']
labels = ['Granitoid','Dolerite','Felsite','Dacite','UIM','LIMB']
# ,'This Study','Bermudez et al.,2016', 'Izett et al., 1991','Koeberl & Sigurddson, 1992 (black)','Koeberl & Sigurddson, 1992 (yellow)']

patches = []
for i in range(len(labels)):
    patches.append(mpatches.Patch(color=colors[i],label=labels[i]))

plt.setp(axs[-1, :], xlabel='SiO$_2$ (Wt%)')
plt.xlim(39,70)
plt.tight_layout()
plt.legend(loc = 'lower center', handles =patches, fontsize = 15, frameon=True, ncol=3,fontsize=12, bbox_to_anchor=(0, -0.5))
axs[0,1].legend(loc =2, frameon=True, ncol=1, bbox_to_anchor=(1.02, 0.9), prop={'size': 12})
plt.savefig('Tektite_drill_core.png')
plt.show()

# %% [markdown]
# # Plotting P2O5 vs CaO:

# %% [markdown]
# Drill core vs. tektite data:

# %%
#Drill core data:
sns.kdeplot(x = granitoid['CaO'],y = granitoid['P2O5'],
            levels=2, alpha = 0.4, color = colors[0], shade = True)
sns.kdeplot(x = dolerite['CaO'],y = dolerite['P2O5'],
            levels=2, alpha = 0.4, color = colors[1], shade = True)
sns.kdeplot(x = Felsite['CaO'],y = Felsite['P2O5'],
            levels=2, alpha = 0.4, color = colors[2], shade = True)
sns.kdeplot(x = Dacite['CaO'],y = Dacite['P2O5'],
            levels=2, alpha = 0.4, color = colors[3], shade = True)
sns.kdeplot(x = UIM['CaO'],y = UIM['P2O5'],
            levels=2, alpha = 0.4, color = colors[4], shade = True)
sns.kdeplot(x = LIMB['CaO'],y = LIMB['P2O5'],
            levels=2, alpha = 0.4, color = colors[5], shade = True)


#Tektite Data: 
plt.scatter(fin_data['CaO'],fin_data['P2O5'],color = 'black', s=15,
        label='This Study')
plt.scatter(bermudez['CaO'],bermudez['P2O5'],marker= '^', s=25,color = '#4d9221',
        label='Bermudez et al.,2016')
plt.scatter(belza['CaO'],belza['P2O5'],marker= 'p',s=25,color = '#35978f', 
        label='Belza et al.,2015')
plt.scatter(izett['CaO'],izett['P2O5'],marker= 'o',s=25,color = '#de77ae',
        label='Izett et al., 1991')
plt.scatter(kbrl_blck['CaO'],kbrl_blck['P2O5'],marker= 's',s=25,color = '#f46d43',
        label='Koeberl & Sigurddson, 1992 (black)')
plt.scatter(kbrl_ylw['CaO'],kbrl_ylw['P2O5'],marker= 's',s=25,color = '#d53e4f',
        label='Koeberl & Sigurddson, 1992 (yellow)')

plt.xlim(0,40)
plt.ylim(-0.05,1.24)
plt.ylabel('P$_2$O$_5$ (Wt%)')
plt.xlabel('CaO (Wt%)')
plt.legend(bbox_to_anchor=(1.02, 0.9),fontsize=9)
plt.legend(loc = 'lower center', handles =patches, fontsize = 15, frameon=True, ncol=3, bbox_to_anchor=(0, -0.5))
plt.title('P$_2$O$_5$ vs. CaO')
plt.show()
